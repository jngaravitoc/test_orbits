# %%
import numpy as np
import plot_orbits
import matplotlib.pyplot as plt
import soda
# %matplotlib inline
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/__init__.py:841: UserWarning: Found matplotlib configuration in ~/.matplotlib/. To conform with the XDG base directory standard, this configuration location has been deprecated on Linux, and the new location is now /home/ngaravito/.config/matplotlib/. Please move your configuration there to ensure that matplotlib will continue to find it in the future.
#   _get_xdg_config_dir())

# %% [markdown]
# # This is a test of the script MWlSgrLMC agains the ipynb Orbits_MW

# %%
# !python3 orbits_NGC.py MWlSgrLMC
plot_orbits.plot_orbits('MWlLMC0Sgr_ICs0.txt')
# Out:
# Host:  0.0 0.0 0.0
# Satellite 1 : -1.0 -41.0 -28.0
# Satellite 2:  16.1 2.35 -6.12
# 13

# %%
# !python3 orbits_NGC.py MWhSgrLMC
plot_orbits.plot_orbits('MWhLMC0Sgr_ICs0.txt')
# Out:
# Host:  0.0 0.0 0.0
# Satellite 1 : -1.0 -41.0 -28.0
# Satellite 2:  16.1 2.35 -6.12
# 13

# %%
# !python3 orbits_NGC.py MWlSgr
# Out:
# Host:  0.0 0.0 0.0
# Satellite 1 : 16.1 2.35 -6.12

# %%
plot_orbits.plot_orbits('MWlSgr_ICs0')
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %%
# !time python3 orbits_NGC.py MWhSgr
# Out:
# Host:  0.0 0.0 0.0
# Satellite 1 : 16.1 2.35 -6.12
# 104.48user 0.39system 1:44.50elapsed 100%CPU (0avgtext+0avgdata 48056maxresident)k
# 0inputs+1312outputs (0major+15480minor)pagefaults 0swaps

# %%
plot_orbits.plot_orbits('MWhSgr_ICs0.txt')
# Out:
# /usr/local/lib/python3.4/dist-packages/matplotlib/axes/_axes.py:545: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "
